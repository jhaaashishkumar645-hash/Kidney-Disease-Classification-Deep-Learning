# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\infinix\\OneDrive\\Documents\\Kidney-Disease-Classification-Deep-Learning\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\infinix\\OneDrive\\Documents\\Kidney-Disease-Classification-Deep-Learning'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    base_model_path: Path
    updated_base_model_path: Path
    params_image_size: list
    params_learning_rate: float
    params_include_top: bool
    params_weights: str
    params_classes: int

# %%
from cnnClassifier.constants import *
from cnnClassifier.utils.common import read_yaml, create_directories

# %%
class ConfigurataionManager:
    def __init__(
        self,
        config_file_path: CONFIG_FILE_PATH,
        params_file_path: PARAMS_FILE_PATH):


        self.config = read_yaml(config_file_path)
        self.params = read_yaml(params_file_path)


        create_directories([self.config.artifacts_root])

        def get_prepare_base_model_config(self) -> PrepareBaseModelConfig:
            config = self.config.prepare_base_model

            create_directories([config.root_dir])

            prepare_base_model_config = PrepareBaseModelConfig(
                root_dir=Path(config.root_dir),
                base_model_path=Path(config.base_model_path),
                updated_base_model_path=Path(config.updated_base_model_path),
                params_image_size=self.params.IMAGE_SIZE,
                params_learning_rate=self.param.LEARNING_RATE,
                params_include_top=self.params.INCLUDE_TOP,
                params_weights=self.params.WEIGHTS,
                param_classes=self.params.CLASSES
            )
            
            return prepare_base_model_config

# %%
import os
import urllib.request as request
from zipfile import ZipFile
import tensorflow as tf

# %%
import tensorflow as tf
from pathlib import Path

from cnnClassifier.entity.config_entity import PrepareBaseModelConfig


class PrepareBaseModel:

    def __init__(self, config: PrepareBaseModelConfig):
        self.config = config

    def get_base_model(self):
        self.model = tf.keras.applications.VGG16(
            input_shape=self.config.params_image_size,
            weights=self.config.params_weights,
            include_top=self.config.params_include_top
        )

        self.save_model(
            path=self.config.base_model_path,
            model=self.model
        )

    @staticmethod
    def _prepare_full_model(
        model,
        classes,
        freeze_all,
        freeze_till,
        learning_rate
    ):

        if freeze_all:
            for layer in model.layers:
                layer.trainable = False

        elif (freeze_till is not None) and (freeze_till > 0):
            for layer in model.layers[:-freeze_till]:
                layer.trainable = False

        flatten_in = tf.keras.layers.Flatten()(model.output)

        prediction = tf.keras.layers.Dense(
            units=classes,
            activation="softmax"
        )(flatten_in)

        full_model = tf.keras.models.Model(
            inputs=model.input,
            outputs=prediction
        )

        full_model.compile(
            optimizer=tf.keras.optimizers.Adam(
                learning_rate=learning_rate
            ),
            loss="categorical_crossentropy",
            metrics=["accuracy"]
        )

        full_model.summary()

        return full_model

    def update_base_model(self):

        self.full_model = self._prepare_full_model(
            model=self.model,
            classes=self.config.params_classes,
            freeze_all=True,
            freeze_till=None,
            learning_rate=self.config.params_learning_rate
        )

        self.save_model(
            path=self.config.updated_base_model_path,
            model=self.full_model
        )

    @staticmethod
    def save_model(path: Path, model: tf.keras.Model):
        model.save(path)

# %%
from cnnClassifier.entity.config_entity import PrepareBaseModelConfig
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from cnnClassifier.entity.config_entity import PrepareBaseModelConfig
#
# ImportError: cannot import name 'PrepareBaseModelConfig' from 'cnnClassifier.entity.config_entity' (C:\Users\infinix\OneDrive\Documents\Kidney-Disease-Classification-Deep-Learning\src\cnnClassifier\entity\config_entity.py)

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\infinix\OneDrive\Documents\Kidney-Disease-Classification-Deep-Learning\kidney\Scripts\python.exe

# %%
import importlib
import cnnClassifier.entity.config_entity as config_entity

importlib.reload(config_entity)

from cnnClassifier.entity.config_entity import PrepareBaseModelConfig
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 6
#       2 import cnnClassifier.entity.config_entity as config_entity
#       3
#       4 importlib.reload(config_entity)
#       5
# ----> 6 from cnnClassifier.entity.config_entity import PrepareBaseModelConfig
#
# ImportError: cannot import name 'PrepareBaseModelConfig' from 'cnnClassifier.entity.config_entity' (C:\Users\infinix\OneDrive\Documents\Kidney-Disease-Classification-Deep-Learning\src\cnnClassifier\entity\config_entity.py)

# %%
import importlib
import cnnClassifier.entity.config_entity as config_entity

importlib.reload(config_entity)

from cnnClassifier.entity.config_entity import PrepareBaseModelConfig
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 6
#       2 import cnnClassifier.entity.config_entity as config_entity
#       3
#       4 importlib.reload(config_entity)
#       5
# ----> 6 from cnnClassifier.entity.config_entity import PrepareBaseModelConfig
#
# ImportError: cannot import name 'PrepareBaseModelConfig' from 'cnnClassifier.entity.config_entity' (C:\Users\infinix\OneDrive\Documents\Kidney-Disease-Classification-Deep-Learning\src\cnnClassifier\entity\config_entity.py)

# %%
import sys
sys.path.insert(0, r"C:\Users\infinix\OneDrive\Documents\Kidney-Disease-Classification-Deep-Learning\src")

# %%
import cnnClassifier.entity.config_entity as ce

print(ce.__file__)
print(dir(ce))
# Out:
# C:\Users\infinix\OneDrive\Documents\Kidney-Disease-Classification-Deep-Learning\src\cnnClassifier\entity\config_entity.py
# ['DataIngestionConfig', 'Path', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'dataclass']

# %%
import cnnClassifier.entity.config_entity as ce

print(ce.__file__)
print(dir(ce))
# Out:
# C:\Users\infinix\OneDrive\Documents\Kidney-Disease-Classification-Deep-Learning\src\cnnClassifier\entity\config_entity.py
# ['DataIngestionConfig', 'Path', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'dataclass']

# %%
import cnnClassifier.entity.config_entity as ce

# %%
print(dir(ce))
# Out:
# ['DataIngestionConfig', 'Path', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'dataclass']

# %%
from pathlib import Path

p = Path(r"C:\Users\infinix\OneDrive\Documents\Kidney-Disease-Classification-Deep-Learning\src\cnnClassifier\entity\config_entity.py")

print("FILE EXISTS:", p.exists())
print("FILE SIZE:", p.stat().st_size, "bytes")
print("\n========== ACTUAL FILE CONTENT ==========\n")
print(p.read_text(encoding="utf-8"))
# Out:
# FILE EXISTS: True
# FILE SIZE: 205 bytes
#
# ========== ACTUAL FILE CONTENT ==========
#
# from dataclasses import dataclass
# from pathlib import Path
#
#
# @dataclass(frozen=True)
# class DataIngestionConfig:
#     root_dir: Path
#     source_URL: str
#     local_data_file: Path
#     unzip_dir: Path

# %%
from pathlib import Path

p = Path(r"C:\Users\infinix\OneDrive\Documents\Kidney-Disease-Classification-Deep-Learning\src\cnnClassifier\entity\config_entity.py")

print(p.stat().st_size)
print("PrepareBaseModelConfig" in p.read_text(encoding="utf-8"))
# Out:
# 205
# False

# %%
from pathlib import Path

p = Path(r"C:\Users\infinix\OneDrive\Documents\Kidney-Disease-Classification-Deep-Learning\src\cnnClassifier\entity\config_entity.py")

code = '''from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzip_dir: Path


@dataclass(frozen=True)
class PrepareBaseModelConfig:
    root_dir: Path
    base_model_path: Path
    updated_base_model_path: Path
    params_image_size: list
    params_weights: str
    params_include_top: bool
    params_classes: int
    params_learning_rate: float
'''

p.write_text(code, encoding="utf-8")

print("FILE WRITTEN SUCCESSFULLY")
print("SIZE:", p.stat().st_size)
print("CONFIG FOUND:", "PrepareBaseModelConfig" in p.read_text(encoding="utf-8"))
# Out:
# FILE WRITTEN SUCCESSFULLY
# SIZE: 491
# CONFIG FOUND: True

# %%
import cnnClassifier.entity.config_entity as ce

print(ce.__file__)
print("PrepareBaseModelConfig" in dir(ce))
print(ce.PrepareBaseModelConfig)
# Out:
# C:\Users\infinix\OneDrive\Documents\Kidney-Disease-Classification-Deep-Learning\src\cnnClassifier\entity\config_entity.py
# False
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 5
#       1 import cnnClassifier.entity.config_entity as ce
#       2
#       3 print(ce.__file__)
#       4 print("PrepareBaseModelConfig" in dir(ce))
# ----> 5 print(ce.PrepareBaseModelConfig)
#
# AttributeError: module 'cnnClassifier.entity.config_entity' has no attribute 'PrepareBaseModelConfig'

# %%
from pathlib import Path

p = Path(r"C:\Users\infinix\OneDrive\Documents\Kidney-Disease-Classification-Deep-Learning\src\cnnClassifier\entity\config_entity.py")

print("EXISTS:", p.exists())
print("SIZE:", p.stat().st_size)
print("HAS CONFIG:", "PrepareBaseModelConfig" in p.read_text(encoding="utf-8"))

print("\n===== FILE CONTENT =====")
print(p.read_text(encoding="utf-8"))
# Out:
# EXISTS: True
# SIZE: 491
# HAS CONFIG: True
#
# ===== FILE CONTENT =====
# from dataclasses import dataclass
# from pathlib import Path
#
#
# @dataclass(frozen=True)
# class DataIngestionConfig:
#     root_dir: Path
#     source_URL: str
#     local_data_file: Path
#     unzip_dir: Path
#
#
# @dataclass(frozen=True)
# class PrepareBaseModelConfig:
#     root_dir: Path
#     base_model_path: Path
#     updated_base_model_path: Path
#     params_image_size: list
#     params_weights: str
#     params_include_top: bool
#     params_classes: int
#     params_learning_rate: float

# %%
import sys

module_name = "cnnClassifier.entity.config_entity"

if module_name in sys.modules:
    del sys.modules[module_name]

print("Old module cache removed")
# Out:
# Old module cache removed

# %%
import cnnClassifier.entity.config_entity as ce

print(ce.__file__)
print("PrepareBaseModelConfig" in dir(ce))
print(ce.PrepareBaseModelConfig)
# Out:
# C:\Users\infinix\OneDrive\Documents\Kidney-Disease-Classification-Deep-Learning\src\cnnClassifier\entity\config_entity.py
# True
# <class 'cnnClassifier.entity.config_entity.PrepareBaseModelConfig'>

# %%
try:

    config = ConfigurationManager()

    prepare_base_model_config = config.get_prepare_base_model_config()

    prepare_base_model = PrepareBaseModel(
        config=prepare_base_model_config
    )

    prepare_base_model.get_base_model()

    prepare_base_model.update_base_model()

except Exception as e:

    raise e
# Out:
# [2026-09-06 00:03:33,058: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-09-06 00:03:33,063: INFO: common: yaml file: params.yaml loaded successfully]
# [2026-09-06 00:03:33,396: WARNING: saving_api: You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`. ]
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
from cnnClassifier.config.configuration import ConfigurationManager

config = ConfigurationManager()

print("ConfigurationManager loaded successfully!")
# Out:
# [2026-09-05 23:57:15,471: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-09-05 23:57:15,499: INFO: common: yaml file: params.yaml loaded successfully]
# ConfigurationManager loaded successfully!

# %%
from cnnClassifier.config.configuration import ConfigurationManager

config = ConfigurationManager()

print(config.config)
# Out:
# [2026-09-05 23:59:04,586: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-09-05 23:59:04,590: INFO: common: yaml file: params.yaml loaded successfully]
# {'artifacts_root': 'artifacts', 'data_ingestion': {'root_dir': 'artifacts/prepare_base_model', 'source_URL': 'https://drive.google.com/uc?id=1eOp1VPkx2e3Qmztcqw3F12wA-n7O9Zla', 'local_data_file': 'artifacts/data_ingestion/data.zip', 'unzip_dir': 'artifacts/data_ingestion', 'prepare_base_model': None, 'base_model_path': 'artifacts/prepare_base_model/base_model.hs', 'updated_base_model_path': 'artifacts/prepare_base_model/base_model_updated.hs'}}

# %%
from cnnClassifier.config.configuration import ConfigurationManager

config = ConfigurationManager()

print(config.config.keys())
# Out:
# [2026-09-06 00:00:49,771: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-09-06 00:00:49,774: INFO: common: yaml file: params.yaml loaded successfully]
# dict_keys(['artifacts_root', 'data_ingestion', 'prepare_base_model'])

# %%
config = ConfigurationManager()

prepare_base_model_config = config.get_prepare_base_model_config()

print(prepare_base_model_config)
# Out:
# [2026-09-06 00:01:25,395: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-09-06 00:01:25,399: INFO: common: yaml file: params.yaml loaded successfully]
# PrepareBaseModelConfig(root_dir=WindowsPath('artifacts/prepare_base_model'), base_model_path=WindowsPath('artifacts/prepare_base_model/base_model.h5'), updated_base_model_path=WindowsPath('artifacts/prepare_base_model/base_model_updated.h5'), params_image_size=BoxList([224, 224, 3]), params_weights='imagenet', params_include_top=False, params_classes=2, params_learning_rate=0.01)

# %%
prepare_base_model = PrepareBaseModel(
    config=prepare_base_model_config
)

prepare_base_model.get_base_model()
# Out:
# ...
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 21s 0us/step
# [2026-09-06 00:02:10,013: WARNING: saving_api: You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`. ]

# %%
prepare_base_model.update_base_model()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ...
