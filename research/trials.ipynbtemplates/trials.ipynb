# %%
#config box
d = {"key":"val", "key1":"val1"}

# %%
d['key1']
# Out:
# 'val1'

# %%
 d.key1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 d.key1
#
# AttributeError: 'dict' object has no attribute 'key1'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key":"val", "key1":"val1"})

# %%
d2.key1
# Out:
# 'val1'

# %%
type(d2)
# Out:
# box.config_box.ConfigBox

# %%
type(d)
# Out:
# dict

# %%
#ensure annotations
def get_prodict(x:int, y:int) -> int:
    return x*y

# %%
get_prodict(x=2, y=3)
# Out:
# 6

# %%
get_prodict(x=2, y="3")
# Out:
# '33'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_prodict(x:int, y:int) -> int:
    return x*y

# %%
get_prodict(x=2, y=3)
# Out:
# 6

# %%
## Download data from gdrive
import gdown

# %%
url="https://drive.google.com/drive/folders/15JUqdxsq1HCLGHlyHnDsPwkVlZvtCCyn?usp=drive_link"

# %%
file_id = url.split("/")[-1]
file_id
# Out:
# '15JUqdxsq1HCLGHlyHnDsPwkVlZvtCCyn?usp=drive_link'

# %%
prefix = 'https://drive.google.com/drive/u/0/folders/15JUqdxsq1HCLGHlyHnDsPwkVlZvtCCyn'
gdown.download(prefix+file_id, "CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone.zip", quiet=False)
# Out:
# ---------------------------------------------------------------------------
# SSLEOFError                               Traceback (most recent call last)
# File ~\OneDrive\Documents\Kidney-Disease-Classification-Deep-Learning\kidney\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File ~\OneDrive\Documents\Kidney-Disease-Classification-Deep-Learning\kidney\Lib\site-packages\urllib3\connectionpool.py:1106, in HTTPSConnectionPool._validate_conn(self, conn)
#    1105 if conn.is_closed:
# -> 1106     conn.connect()
#    1108 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# ...

# %%
import gdown

file_id = "1eOp1VPkx2e3Qmztcqw3F12wA-n7O9Zla"

url = f"https://drive.google.com/uc?id={file_id}"

gdown.download(
    url,
    "CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone.zip",
    quiet=False
)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1eOp1VPkx2e3Qmztcqw3F12wA-n7O9Zla
# From (redirected): https://drive.google.com/uc?id=1eOp1VPkx2e3Qmztcqw3F12wA-n7O9Zla&confirm=t&uuid=c0712017-0c76-4091-9b63-02a70f3574fb
# To: c:\Users\infinix\OneDrive\Documents\Kidney-Disease-Classification-Deep-Learning\research\trials.ipynbtemplates\CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone.zip
# 100%|██████████| 1.63G/1.63G [07:21<00:00, 3.69MB/s]
# 'CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone.zip'
